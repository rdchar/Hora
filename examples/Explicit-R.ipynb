# %%
from hypernetworks.core.Hypernetwork import Hypernetwork
from hypernetworks.core.Hypersimplex import VERTEX, ALPHA, BETA, hstype_to_str
from hypernetworks.utils.HTCompiler import load_parser, compile_hn
from hypernetworks.utils.HTTools import remove_special
from hypernetworks.utils.HTGraph import draw_hn

from IPython.display import Image

parser = load_parser()

pictures_dir="pictures/"

# %%
hn = Hypernetwork()

compile_hn(hn, parser, """
    chair=<leg_1, leg_2, leg_3, leg_4, seat, back; R_chair+>
""")

draw_hn(hn, fname=pictures_dir+"explicit-chair-hn", view=False, show_hstype=False)
Image(filename=pictures_dir+"explicit-chair-hn.png", width=600, height=1200)

# %%
hn = Hypernetwork()

compile_hn(hn, parser, """
    a_above_b=<a, b; R_x_above_y+>
""")

draw_hn(hn, fname=pictures_dir+"a-above-b-hn", view=False, show_hstype=False)
Image(filename=pictures_dir+"a-above-b-hn.png", width=250, height=1200)

# %%
hn = Hypernetwork()

compile_hn(hn, parser, """
b_above_a=<b, a; R_x_above_y+>
""")

draw_hn(hn, fname=pictures_dir+"b-above-a-hn", view=False, show_hstype=False)
Image(filename=pictures_dir+"b-above-a-hn.png", width=250, height=1200)
